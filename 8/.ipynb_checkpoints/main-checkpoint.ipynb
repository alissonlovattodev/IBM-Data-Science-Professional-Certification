# %%
import numpy as np  
import pandas as pd

# %%
df_dataScience=pd.read_csv('Topic_Survey_Assignment.csv', index_col=0)
df_dataScience.head(6)
# Out:
#                             Very interested  Somewhat interested  \
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
# Machine Learning                       1629                  477
#
#                             Not interested
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136
# Machine Learning                        74

# %%
df_dataScience = pd.read_csv("Topic_Survey_Assignment.csv")

df_dataScience.rename(columns={'Unnamed: 0':'Topic'}, inplace=True )
df_dataScience.set_index('Topic', inplace = True)

#Sort the dataframe in descending order of Very interested
df_dataScience.sort_values(['Very interested'], ascending = False, axis = 0, inplace = True)

#converting the dataframe into percentages 
df_dataScience = df_dataScience.divide(2233)
df_dataScience = df_dataScience.multiply(100)
df_dataScience = df_dataScience.round(2)
df_dataScience.head()
# Out:
#                             Very interested  Somewhat interested  \
# Topic
# Data Analysis / Statistics            75.59                19.88
# Machine Learning                      72.95                21.36
# Data Visualization                    60.01                32.87
# Big Data (Spark / Hadoop)             59.65                32.65
# Deep Learning                         56.56                34.48
#
#                             Not interested
# Topic
# Data Analysis / Statistics            2.69
# Machine Learning                      3.31
# Data Visualization                    4.57
# Big Data (Spark / Hadoop)             5.69
# Deep Learning                         6.09

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')

color_list = ['#5cb85c', '#5bc0de', '#d9534f']

ax = df_dataScience.plot.bar(figsize = (20, 8), alpha = 0.8, width = 0.8, color = color_list)
ax.set_title("Percentage of Respondents' Interest in Data Science Areas", fontsize = 16)

legend = ax.legend(fontsize='14')
ax.tick_params(axis='x', labelsize=14)
ax.set_xlabel('')

#Putting the percentage values on top of each bar
for p in ax.patches:
    ax.annotate(str(p.get_height()) + '%', (p.get_x() * 1.005, p.get_height() * 1.005), fontsize = 14)
    
ax.set_facecolor('xkcd:white')
plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=False, labelbottom=True)

# %%
df_initial = pd.read_csv("Police_Department_Incidents_-_Previous_Year__2016_.csv")

#print(df_initial.head(10))
df_PdDistrict = df_initial[['PdDistrict', 'X']]
df_sfcrime = df_PdDistrict.groupby(['PdDistrict']).count()
df_sfcrime = df_sfcrime.reset_index()
df_sfcrime.columns = ['Neighborhood', 'Count']
df_sfcrime.head(10)
# Out:
#   Neighborhood  Count
# 0      BAYVIEW  14303
# 1      CENTRAL  17666
# 2    INGLESIDE  11594
# 3      MISSION  19503
# 4     NORTHERN  20100
# 5         PARK   8699
# 6     RICHMOND   8922
# 7     SOUTHERN  28445
# 8      TARAVAL  11325
# 9   TENDERLOIN   9942

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# !pip install folium
import folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Alisson Lovatto\anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.2.0               |     pyhd8ed1ab_1         711 KB  conda-forge
#     branca-0.5.0               |     pyhd8ed1ab_0          26 KB  conda-forge
#     conda-22.9.0               |   py39hcbf5309_2         985 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.2.0-pyhd8ed1ab_1 None
#   branca             conda-forge/noarch::branca-0.5.0-pyhd8ed1ab_0 None
#   folium             conda-forge/noarch::folium-0.5.0-py_0 None
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39 None
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1 None
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-22.9.0-py39haa95532_0 --> conda-forge::conda-22.9.0-py39hcbf5309_2 None
#
#
#
# Downloading and Extracting Packages
#
# branca-0.5.0         | 26 KB     |            |   0%
# branca-0.5.0         | 26 KB     | ######     |  61%
# branca-0.5.0         | 26 KB     | ########## | 100%
# branca-0.5.0         | 26 KB     | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | ########## | 100%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# altair-4.2.0         | 711 KB    |            |   0%
# altair-4.2.0         | 711 KB    | ##2        |  23%
# altair-4.2.0         | 711 KB    | ########## | 100%
# altair-4.2.0         | 711 KB    | ########## | 100%
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ###5       |  35%
# folium-0.5.0         | 45 KB     | ########## | 100%
# folium-0.5.0         | 45 KB     | ########## | 100%
#
# conda-22.9.0         | 985 KB    |            |   0%
# conda-22.9.0         | 985 KB    | ###5       |  36%
# conda-22.9.0         | 985 KB    | ########## | 100%
# conda-22.9.0         | 985 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
# Requirement already satisfied: folium in c:\users\alisson lovatto\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy in c:\users\alisson lovatto\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.3.0 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: requests in c:\users\alisson lovatto\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alisson lovatto\anaconda3\lib\site-packages (from requests->folium) (1.26.11)

# %%
from IPython.display import display

sf_geo = r'san-francisco.geojson.json'
sf_map = folium.Map(location = [37.76, -122.45], zoom_start = 12)
sf_map.choropleth(
    geo_data = sf_geo, 
    data = df_sfcrime, 
    columns = ['Neighborhood', 'Count'], 
    key_on='feature.properties.DISTRICT', 
    fill_color = 'YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2, 
    legend_name='Crime Rate in San Francisco'
)

sf_map
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5284\3255673319.py in <module>
#       3 sf_geo = r'san-francisco.geojson'
#       4 sf_map = folium.Map(location = [37.76, -122.45], zoom_start = 12)
# ----> 5 sf_map.choropleth(
#       6     geo_data = sf_geo,
#       7     data = df_sfcrime,
#
# ~\anaconda3\lib\site-packages\folium\folium.py in choropleth(self, geo_data, data, columns, key_on, threshold_scale, fill_color, fill_opacity, line_color, line_weight, line_opacity, name, legend_name, topojson, reset, smooth_factor, highlight)
#     320                 smooth_factor=smooth_factor)
#     321         else:
# --> 322             geo_json = GeoJson(
#     323                 geo_data,
#     324                 name=name,
#
# ~\anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, name, overlay, control, smooth_factor, highlight_function)
#     479                 self.data = json.loads(data)
#     480             else:  # This is a filename
# --> 481                 with open(data) as f:
#     482                     self.data = json.loads(f.read())
#     483         elif data.__class__.__name__ in ['GeoDataFrame', 'GeoSeries']:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'san-francisco.geojson'
